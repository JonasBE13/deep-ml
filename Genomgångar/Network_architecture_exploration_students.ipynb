# %% [markdown]
# # Network Architecture Exploration: Understanding Underfitting and Overfitting
# ## Background
# This exercise aims to demonstrate how different neural network architectures can lead to underfitting or overfitting. You will experiment with various configurations of a fully connected neural network to observe these phenomena.
#
# ## Underfitting
# Occurs when a model is too simple to capture the underlying pattern of the data. Often caused by having too few layers or neurons.
#
# ## Overfitting
# Happens when a model learns the training data too well, including the noise, making it perform poorly on new, unseen data. This can result from having too many layers or neurons.

# %% [markdown]
# ## Setup
# Import the necessary libraries and prepare the dataset.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# Generate synthetic data
X, y = make_circles(n_samples=6000, noise=0.09, factor=0.5, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=42
)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\jonas\Documents\GitHub\DEEP ML\deep-ml\deepml\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Model Building
# Define a function to create a model with a variable number of layers and neurons.

# %%
def build_model(num_layers=1, num_neurons=10, activation_function="sigmoid"):
    model = tf.keras.models.Sequential()

    model.add(
        tf.keras.layers.Dense(
            num_neurons, activation=activation_function, input_shape=(2,)
        )
    )

    for _ in range(num_layers - 1):
        model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function))

    model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

    return model

# %% [markdown]
# # Train and Evaluate Model Script
# Below is a skeleton for a function to train and evaluate your models. Fill in the missing parts as indicated by the comments.

# %%
def train_and_evaluate_model(model, epochs=50, plot=True):
    # Train the model
    history = model.fit(
        X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2
    )

    # Evaluate the model on the test set
    # TASK: Fill in the evaluation code here
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    predictions = model.predict(X_test) > 0.5

    # Plotting (if enabled)
    if plot:
        plt.figure(figsize=(18, 5))

        # Plot training and validation accuracy
        # TASK: Add code to plot training history

        plt.subplot(1, 3, 1)
        plt.plot(history.history["accuracy"], label="Accuracy (training data)")
        plt.plot(history.history["val_accuracy"], label="Accuracy (validation data)")
        plt.title("Training and Validation accurcy")
        plt.ylabel("Accuracy")
        plt.xlabel("Epoch")
        plt.legend()

        # Plot model predictions vs. ground truth on the test set
        # TASK: Add code to plot model predictions and ground truth
        # predictions
        plt.subplot(1, 3, 2)
        plt.scatter(
            X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm
        )
        plt.title("Model Predictions on Test Data")
        plt.xlabel("Feature 1")
        plt.ylabel("Feature 2")

        # ground truth

        plt.subplot(1, 3, 3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title("Ground truth for Test Data")
        plt.xlabel("Feature 1")
        plt.ylabel("Feature 2")

        plt.show()

    # TASK: Print or return any other metrics or plots you think are necessary

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)
    print(f"Train Accuracy (model.eval): {train_accuracy:.4f}")

    # print("Training History:")
    # print("Loss:", history.history['loss'])
    # print("Accuracy:", history.history['accuracy'])
    # print("Validation Loss:", history.history['val_loss'])
    # print("Validation Accuracy:", history.history['val_accuracy'])

# %%
# 50 epochs
# Example of using the function with a specific architecture
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6912
# Test Accuracy: 0.5153
# Train Accuracy (model.eval): 0.5097

# %%
# 100 epochs
# Example of using the function with a specific architecture
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=100)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.1920
# Test Accuracy: 0.9893
# Train Accuracy (model.eval): 0.9840

# %% [markdown]
# # Experimentation
# ## Task 1: Underfitting
# 1. Create and train a model with very few layers and/or neurons (e.g., 1 layer with 5 neurons).
# 2. Evaluate Performance:
#     * Plot training and validation accuracy over epochs.
#     * Plot model predictions vs. ground truth on the test data.
#     * Analyze if the model's performance is poor on both training and test data, which indicates underfitting.
# ## Task 2: Overfitting
# 1. Create a model with an excessive number of layers and/or neurons (e.g., 5 layers with 100 neurons each) and increased number of epochs.
# 2. Evaluate Performance:
#     * Observe the training and validation accuracy plots for a wide gap, indicating overfitting.
#     * Compare model predictions with ground truth for the test data.
#     * Look for high training accuracy but poor test accuracy.
# ## Task 3: Balanced Model
# 1. Experiment to find a balanced architecture.
# 2. Evaluate Performance:
#     * Ensure the training and validation accuracy are both high and close to each other.
#     * The model's predictions should closely match the ground truth for the test data.
#     * The model should not show signs of significant underfitting or overfitting.

# %%
### UNDERFITTING ###
model = build_model(num_layers=1, num_neurons=5)
train_and_evaluate_model(model, epochs=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jonas\Documents\GitHub\DEEP ML\deep-ml\Genomgångar\Network_architecture_exploration_students.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/jonas/Documents/GitHub/DEEP%20ML/deep-ml/Genomg%C3%A5ngar/Network_architecture_exploration_students.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> ### UNDERFITTING ###
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jonas/Documents/GitHub/DEEP%20ML/deep-ml/Genomg%C3%A5ngar/Network_architecture_exploration_students.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> model = build_model(num_layers=1, num_neurons=5)
#       <a href='vscode-notebook-cell:/c%3A/Users/jonas/Documents/GitHub/DEEP%20ML/deep-ml/Genomg%C3%A5ngar/Network_architecture_exploration_students.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> train_and_evaluate_model(model, epochs=50)
#
# NameError: name 'build_model' is not defined

# %%
### UNDERFITTING ###
model = build_model(num_layers=1, num_neurons=5)
train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6634
# Test Accuracy: 0.8463
# Train Accuracy (model.eval): 0.8407

# %%
### OVERFITTING ###
model = build_model(num_layers=5, num_neurons=100)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6935
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %%
### Balanced, 10 neurons ###
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=100)
# Out:
# 94/94 [==============================] - 0s 2ms/step
# Test Loss: 0.1118
# Test Accuracy: 0.9963
# Train Accuracy (model.eval): 0.9947

# %%
### Balanced, 20 neurons ###
model = build_model(num_layers=2, num_neurons=20)
train_and_evaluate_model(model, epochs=100)
# Out:
# 94/94 [==============================] - 0s 2ms/step
# Test Loss: 0.0508
# Test Accuracy: 0.9973
# Train Accuracy (model.eval): 0.9960

# %%
### Balanced, 10 neurons ###
model = build_model(num_layers=4, num_neurons=10)
train_and_evaluate_model(model, epochs=100)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.0879
# Test Accuracy: 0.9933
# Train Accuracy (model.eval): 0.9910

# %%
### Balanced, 20 neurons ###
model = build_model(num_layers=4, num_neurons=20)
train_and_evaluate_model(model, epochs=100)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.0700
# Test Accuracy: 0.9967
# Train Accuracy (model.eval): 0.9953

# %% [markdown]
# # Evaluation and Analysis
# Use similar evaluation and visualization code as in the previous exercise to assess model performance.
# Answer questions like:
# 1. What signs of underfitting did you observe?
# 2. What were the indications of overfitting?
# 3. Describe the architecture of the balanced model and its performance.
#
# # Conclusion
# Reflect on the importance of matching model complexity with the problem complexity and discuss the trade-offs involved in designing neural network architectures.

# %% [markdown]
# ------------------

# %% [markdown]
# # Regularization Technique: Early Stopping
# ## Objective
# Understand how early stopping can be used as a regularization technique to prevent overfitting and improve the generalization of neural networks.
#
# ## Background
# Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method, such as gradient descent. It involves stopping the training process if the model's performance on a validation set starts to deteriorate, meaning the model begins to learn noise and details from the training data that negatively impact its performance on unseen data.
#
# ## How Early Stopping Works
# * Monitor the model's performance on a validation set during training.
# * If the performance on the validation set stops improving or starts to worsen, stop the training.
# * Often, a 'patience' parameter is set to allow some leeway, meaning training will stop only after the model's performance hasn't improved for a specified number of epochs.

# %% [markdown]
# # Implementation in TensorFlow
# TensorFlow provides an easy way to implement early stopping through callbacks. Here’s how you can add early stopping to your training process:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

# Include this callback in the model's fit method
model.fit(
    X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0680 - accuracy: 0.9954 - val_loss: 0.0650 - val_accuracy: 0.9950
# Epoch 2/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9950 - val_loss: 0.0544 - val_accuracy: 0.9933
# Epoch 3/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9954 - val_loss: 0.0464 - val_accuracy: 0.9950
# Epoch 4/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9962 - val_loss: 0.0431 - val_accuracy: 0.9950
# Epoch 5/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9954 - val_loss: 0.0360 - val_accuracy: 0.9967
# Epoch 6/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9962 - val_loss: 0.0324 - val_accuracy: 0.9967
# Epoch 7/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9967 - val_loss: 0.0295 - val_accuracy: 0.9983
# Epoch 8/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9954 - val_loss: 0.0268 - val_accuracy: 0.9967
# Epoch 9/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9958 - val_loss: 0.0296 - val_accuracy: 0.9950
# Epoch 10/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 0.9954 - val_loss: 0.0235 - val_accuracy: 0.9983
# Epoch 11/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9967 - val_loss: 0.0215 - val_accuracy: 0.9967
# Epoch 12/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9954 - val_loss: 0.0226 - val_accuracy: 0.9967
# Epoch 13/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 0.0203 - val_accuracy: 0.9967
# Epoch 14/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9962 - val_loss: 0.0200 - val_accuracy: 0.9967
# Epoch 15/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9967 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 16/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9950 - val_loss: 0.0206 - val_accuracy: 0.9950
# Epoch 17/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9971 - val_loss: 0.0160 - val_accuracy: 0.9983
# Epoch 18/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9967 - val_loss: 0.0160 - val_accuracy: 0.9967
# Epoch 19/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9967 - val_loss: 0.0182 - val_accuracy: 0.9950
# Epoch 20/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 0.0183 - val_accuracy: 0.9967
# Epoch 21/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9971 - val_loss: 0.0146 - val_accuracy: 0.9950
# Epoch 22/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.0145 - val_accuracy: 0.9950
# Epoch 23/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0130 - val_accuracy: 0.9983
# Epoch 24/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9971 - val_loss: 0.0131 - val_accuracy: 0.9950
# Epoch 25/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9967 - val_loss: 0.0127 - val_accuracy: 0.9983
# Epoch 26/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 27/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.0134 - val_accuracy: 0.9950
# Epoch 28/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9967 - val_loss: 0.0159 - val_accuracy: 0.9967
# Epoch 29/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0113 - val_accuracy: 0.9983
# Epoch 30/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.0118 - val_accuracy: 0.9967
# Epoch 31/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 32/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.0112 - val_accuracy: 0.9967
# Epoch 33/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9975 - val_loss: 0.0130 - val_accuracy: 0.9967
# Epoch 34/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.0115 - val_accuracy: 0.9967
# Epoch 35/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0103 - val_accuracy: 0.9967
# Epoch 36/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 37/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.0131 - val_accuracy: 0.9967
# Epoch 38/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9975 - val_loss: 0.0139 - val_accuracy: 0.9950
# Epoch 39/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0153 - val_accuracy: 0.9933
# Epoch 40/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.0109 - val_accuracy: 0.9950

# %%
def train_and_evaluate_model(model, epochs=100, plot=True):
    # Train the model
    early_stopping = EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    history = model.fit(
        X_train,
        y_train,
        epochs=epochs,
        verbose=0,
        validation_split=0.2,
        callbacks=[early_stopping],
    )

    # Evaluate the model on the test set
    # TASK: Fill in the evaluation code here
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    predictions = model.predict(X_test) > 0.5

    # Plotting (if enabled)
    if plot:
        plt.figure(figsize=(18, 5))

        # Plot training and validation accuracy
        # TASK: Add code to plot training history

        plt.subplot(1, 3, 1)
        plt.plot(history.history["accuracy"], label="Accuracy (training data)")
        plt.plot(history.history["val_accuracy"], label="Accuracy (validation data)")
        plt.title("Training and Validation accurcy")
        plt.ylabel("Accuracy")
        plt.xlabel("Epoch")
        plt.legend()

        # Plot model predictions vs. ground truth on the test set
        # TASK: Add code to plot model predictions and ground truth
        # predictions
        plt.subplot(1, 3, 2)
        plt.scatter(
            X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm
        )
        plt.title("Model Predictions on Test Data")
        plt.xlabel("Feature 1")
        plt.ylabel("Feature 2")

        # ground truth

        plt.subplot(1, 3, 3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title("Ground truth for Test Data")
        plt.xlabel("Feature 1")
        plt.ylabel("Feature 2")

        plt.show()

    # TASK: Print or return any other metrics or plots you think are necessary

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)
    print(f"Train Accuracy (model.eval): {train_accuracy:.4f}")

    # print("Training History:")
    # print("Loss:", history.history['loss'])
    # print("Accuracy:", history.history['accuracy'])
    # print("Validation Loss:", history.history['val_loss'])
    # print("Validation Accuracy:", history.history['val_accuracy'])

# %%
### OVERFITTING ###
### 5 patience ###
model = build_model(num_layers=5, num_neurons=100)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6962
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %%
model = build_model(num_layers=5, num_neurons=100)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6969
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %%
### OVERFITTING ###
### 50 patience ###
model = build_model(num_layers=5, num_neurons=100)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6969
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %%
model = build_model(num_layers=5, num_neurons=25)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6951
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %%
model = build_model(num_layers=5, num_neurons=10)
train_and_evaluate_model(model, epochs=300)
# Out:
# 94/94 [==============================] - 0s 3ms/step
# Test Loss: 0.6932
# Test Accuracy: 0.4973
# Train Accuracy (model.eval): 0.5027

# %% [markdown]
# ## Task
# 1. Add early stopping to your neural network training process using the above code snippet.
# 2. Experiment with different values for the patience parameter and observe how it impacts the training process and the model's performance.
#
# ## Analysis and Questions
# * How does early stopping affect the number of epochs for which your model trains?
# * Did you observe any improvements in the generalization of your model to the test data?
# * How does the patience parameter impact the effectiveness of early stopping?
#
# ## Conclusion
# Reflect on the importance of regularization techniques like early stopping in preventing overfitting and improving model generalization.
